# %%
import networkx as nx
import matplotlib.pyplot as plt

# Define hypergraph edges
hyperedges = [[1, 2, 3], [3, 4, 5], [5, 6]]

# Create a graph to represent the hypergraph
G = nx.Graph()

# Add nodes and hyperedges
for hyperedge in hyperedges:
    G.add_nodes_from(hyperedge)
    for i in range(len(hyperedge)):
        for j in range(i + 1, len(hyperedge)):
            G.add_edge(hyperedge[i], hyperedge[j])

# Draw the hypergraph
nx.draw(G, with_labels=True, node_color="skyblue", node_size=500)
plt.show()

# %%
import hypernetx as hnx
import matplotlib.pyplot as plt

# Define a hypergraph
edges = {'e1': {1, 2, 3}, 'e2': {3, 4, 5}, 'e3': {5, 6}}

# Create the hypergraph
H = hnx.Hypergraph(edges)

# Plot the hypergraph
hnx.draw(H)
plt.show()
